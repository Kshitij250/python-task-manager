# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshitij250/python-task-manager/blob/main/Task_Management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Task Management Application

tasks = []

def add_task():
    name = input("Enter task name: ")
    priority = input("Enter priority (High / Medium / Low): ").capitalize()

    task = {
        "name": name,
        "completed": False,
        "priority": priority
    }
    tasks.append(task)
    print("Task added successfully!\n")

# %%
def view_tasks():
    if not tasks:
        print("No tasks available.\n")
        return

    print("\nTask List:")
    for index, task in enumerate(tasks, start=1):
        status = "Completed" if task["completed"] else "Pending"
        print(f"{index}. {task['name']} | Status: {status} | Priority: {task['priority']}")
    print()

# %%
def mark_completed():
    view_tasks()
    if len(tasks) == 0:
        return

    task_no = input("Enter task number to mark as completed: ")

    if task_no.isdigit():
        task_no = int(task_no)
        if 1 <= task_no <= len(tasks):
            tasks[task_no - 1]["completed"] = True
            print("Task marked as completed!\n")
        else:
            print("Invalid task number.\n")
    else:
        print(" Please enter a valid number.\n")

# %%
def remove_task():
    view_tasks()
    if len(tasks) == 0:
        return

    task_no = input("Enter task number to remove: ")

    if task_no.isdigit():
        task_no = int(task_no)
        if 1 <= task_no <= len(tasks):
            removed_task = tasks.pop(task_no - 1)
            print(f"Task '{removed_task['name']}' removed successfully!\n")
        else:
            print("Invalid task number.\n")
    else:
        print("Please enter a valid number.\n")

# %%
def show_menu():
    print("Secret Agency Task Manager")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Mark Task as Completed")
    print("4. Remove Task")
    print("5. Exit")

# %%
while True:
    show_menu()
    choice = input("Choose an option (1-5): ")

    if choice == "1":
        add_task()
    elif choice == "2":
        view_tasks()
    elif choice == "3":
        mark_completed()
    elif choice == "4":
        remove_task()
    elif choice == "5":
        print("Mission Complete. Exiting Task Manager.")
        break
    else:
        print("Invalid choice. Please select again.\n")
# Out:
# Secret Agency Task Manager
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Choose an option (1-5): 1
# Enter task name: file checking
# Enter priority (High / Medium / Low): medium
# ✅ Task added successfully!
#
# Secret Agency Task Manager
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Choose an option (1-5): 2
#
# 📋 Task List:
# 1. file checking | Status: Pending | Priority: Medium
#
# Secret Agency Task Manager
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Choose an option (1-5): 3
#
# 📋 Task List:
# 1. file checking | Status: Pending | Priority: Medium
#
# Enter task number to mark as completed: 1
# Task marked as completed!
#
# Secret Agency Task Manager
# 1. Add Task
# 2. View Tasks
# 3. Mark Task as Completed
# 4. Remove Task
# 5. Exit
# Choose an option (1-5): 2
#
# 📋 Task List:
# 1. file checking | Status: Completed | Priority: Medium
#
# ...
